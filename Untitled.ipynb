# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w = .001
v = .0005
pi = 3.14159
r = np.arange(0,.005,.00001)

# %%
plt.plot(r,2*np.exp(-2*r**2/(w*v))/(pi*w*v))

# %%
plt.plot(r,2*np.exp(-2*r**2/w**2)/(pi*w**2))
